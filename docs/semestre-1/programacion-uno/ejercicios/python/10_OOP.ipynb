# %% [markdown]
# # Programación Orientada a Objetos 🧩
#
# En este cuaderno se introduce el paradigma de programación orientada a objetos (POO) en Python, definiendo clases, atributos y métodos para modelar entidades del mundo real.
#
# **Cómo usar este cuaderno:** ejecuta la celda para definir la clase y crear una instancia de prueba.
#
# ---

# %% [markdown]
# ### Ejercicio: Clase Bicicleta
#
# **Objetivo:** definir una clase `Bicicleta` con atributos (marca, color, tamaño, tipo) y métodos para obtener estos valores y mostrar la información del objeto de manera legible.
#
# **Entradas:** datos de inicialización de la bicicleta.
#
# **Salida:** creación del objeto e impresión de sus detalles.

# %%
class Bicicleta:
    def __init__(self, marca, color, tamano, tipo):
        self.marca = marca
        self.color = color
        self.tamano = tamano
        self.tipo = tipo

    # Métodos
    def get_marca(self):
        return self.marca

    def get_color(self):
        return self.color

    def get_tamano(self):
        return self.tamano

    def get_tipo(self):
        return self.tipo

    # Método para imprimir
    def __str__(self):
        print(f"Marca: {self.marca}\nColor: {self.color}\nTamaño: {self.tamano}\nTipo: {self.tipo}")


bicicleta1 = Bicicleta("GT", "Azul", "M", "MTB")
bicicleta1.__str__()

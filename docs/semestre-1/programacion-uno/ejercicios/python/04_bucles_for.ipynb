# %% [markdown]
# # Ejercicios con Bucles For ➰
#
# En este cuaderno se presentan ejercicios para practicar la iteración definida utilizando el bucle `for` en Python, aplicándolo a cadenas de texto, rangos numéricos y simulaciones.
#
# **Cómo usar este cuaderno:** ejecuta cada celda, ingresa los datos solicitados y experimenta con diferentes valores.
#
# ---

# %% [markdown]
# ### Ejercicio: Formateo de fecha
#
# **Objetivo:** recibir una fecha en formato `dd/mm/aaaa` y reordenarla a `aaaa-mm-dd` utilizando rebanado de cadenas (slicing).
#
# **Entradas:** cadena de fecha (ej. 15/02/2006).
#
# **Salida:** fecha formateada.

# %%
print("CAMBIAR FORMATO DE FECHA aaaa-mm-dd")
print("===================================")

fecha = input("Ingrese la fecha en formato dd/mm/aaaa: ")
anio = fecha[6:]
mes = fecha[3:5]
dia = fecha[:2]
print(f"{anio}-{mes}-{dia}")
# Out:
# CAMBIAR FORMATO DE FECHA aaaa-mm-dd
# ...
# 2006-02-15

# %% [markdown]
# ### Ejercicio: Simulación de dados (Frecuencia)
#
# **Objetivo:** simular 300,000 tiradas de un dado utilizando un bucle `for` y contar la frecuencia de cada cara.
#
# **Entradas:** ninguna.
#
# **Salida:** cantidad de veces que salió cada cara (1-6).

# %%
print("CANTIDAD DE NUMEROS QUE SALIERON AL TIRAR UN DADO")
print("=================================================")
import random
def tirada_dados():
    return random.randint(1,6)
num_tiradas = 300000
contador_de_1 = 0
contador_de_2 = 0
contador_de_3 = 0
contador_de_4 = 0
contador_de_5 = 0
contador_de_6 = 0
for i in range(num_tiradas):
    dado = tirada_dados()
    if dado == 1:
        contador_de_1 += 1
    elif dado == 2:
        contador_de_2 += 1
    elif dado == 3:
        contador_de_3 += 1
    elif dado == 4:
        contador_de_4 += 1
    elif dado == 5:
        contador_de_5 += 1
    else:
        contador_de_6 += 1
print(f"La cantidad de caras 1, salio {contador_de_1} veces")
print(f"La cantidad de caras 2, salio {contador_de_2} veces")
print(f"La cantidad de caras 3, salio {contador_de_3} veces")
print(f"La cantidad de caras 4, salio {contador_de_4} veces")
print(f"La cantidad de caras 5, salio {contador_de_5} veces")
print(f"La cantidad de caras 6, salio {contador_de_6} veces")
# Out:
# CANTIDAD DE NUMEROS QUE SALIERON AL TIRAR UN DADO
# ...
# La cantidad de caras 1, salio 50145 veces
# La cantidad de caras 2, salio 49945 veces
# La cantidad de caras 3, salio 50198 veces
# La cantidad de caras 4, salio 50030 veces
# La cantidad de caras 5, salio 50215 veces
# La cantidad de caras 6, salio 49467 veces

# %% [markdown]
# ### Ejercicio: Recorrer frase por índice
#
# **Objetivo:** recorrer una frase letra por letra utilizando sus índices (`range(len(frase))`) e imprimir cada caracter.
#
# **Entradas:** una frase.
#
# **Salida:** impresión vertical de los caracteres.

# %%
print("FRASE DIVIDIDA")
print("==============")
frase = input("Ingrese una frase a dividir: ")
indice = 1
tamano = len(frase)
for indice in range(tamano):
    letra_inicial = frase[indice]
    print(letra_inicial)
# Out:
# FRASE DIVIDIDA
# ...
# H
# o
# l
# a

# %% [markdown]
# ### Ejercicio: Recorrer frase por elemento
#
# **Objetivo:** recorrer una frase letra por letra iterando directamente sobre la cadena (`for letra in frase`) e imprimir cada caracter.
#
# **Entradas:** una frase.
#
# **Salida:** impresión vertical de los caracteres.

# %%
print("FRASE DIVIDIDA PARTE 2")
print("======================")
frase = input("Ingrese una frase a dividir: ")
for letra in frase:
    print(letra)
# Out:
# FRASE DIVIDIDA PARTE 2
# ...
# H
# o
# l
# a

# %% [markdown]
# ### Ejercicio: Frase invertida
#
# **Objetivo:** imprimir una frase en orden inverso recorriendo la cadena invertida (`frase[::-1]`).
#
# **Entradas:** una frase.
#
# **Salida:** impresión vertical de los caracteres en orden inverso.

# %%
print("FRASE INVERTIDA Y REBANADA")
print("==========================")
frase = input("Ingrese una frase a invertir: ")
for letra in frase[::-1]:
    print(letra)
# Out:
# FRASE INVERTIDA Y REBANADA
# ...
# a
# l
# O
# H

# %% [markdown]
# ### Ejercicio: Lipograma (Casi todo el alfabeto)
#
# **Objetivo:** verificar si una frase contiene exactamente todas las letras del abecedario menos una (longitud de letras únicas igual a 26).
#
# **Entradas:** una frase.
#
# **Salida:** `True` si cumple la condición, `False` en caso contrario.

# %%
print("LIPOGRAMA")
print("=========")


def es_lipograma(cadena):
    abecedario = "abcdefghijklmnñopqrstuvwxyz"
    letras_unicas = ""
    for letra in cadena.lower():
        if letra in abecedario and letra not in letras_unicas:
            letras_unicas += letra
    return len(letras_unicas) == len(abecedario) - 1


frase = input("Escribe la frase que desea saber si es pangrama: ")
print(es_lipograma(frase))
# Out:
# LIPOGRAMA
# ...
# False

# %% [markdown]
# ### Ejercicio: Pangrama
#
# **Objetivo:** determinar si una frase es un pangrama (contiene todas las letras del abecedario español, incluyendo la ñ, al menos una vez). Se normalizan las vocales con tilde.
#
# **Entradas:** una frase.
#
# **Salida:** `True` si es pangrama, `False` en caso contrario.

# %%
print("PANGRAMA")
print("========")

def normaliza_cadena(cadena):
    caracteres = "áéíóúü"
    normalizados = "aeiouu"
    cadena_nueva = ""
    for letra in cadena.lower():
        i = caracteres.find(letra)
        if i >= 0:
            cadena_nueva += normalizados[i]
        else:
            cadena_nueva += letra
    return cadena_nueva


def es_pangrama(cadena):
    abcdario = "abcdefghijklmnñopqrstuvwxyz"
    aux = normaliza_cadena(cadena)
    for letra in abcdario:
        if letra not in aux:
            return False
    return True


frase = input("Escribe la frase que desea saber si es pangrama: ")
print(es_pangrama(frase))

normailizado = input("Ingrese otra frase con muchas tildes y caracteres: ")
print(normaliza_cadena(normailizado))
# Out:
# PANGRAMA
# ...
# False
# origamizacion

# %% [markdown]
# ### Ejercicio: Promedio de suma de dados
#
# **Objetivo:** simular 20 tiradas de dos dados y calcular el promedio de la suma de los valores obtenidos.
#
# **Entradas:** ninguna.
#
# **Salida:** promedio de las sumas.

# %%
print("PROMEDIO DE LA SUMA DE LAS TIRADAS DE DOS DADOS")
print("===============================================")
import random
def tirada_dados():
    return random.randint(1,6)


num_tiradas = 20
suma_resultados = 0
for i in range(num_tiradas):
    dado1 = tirada_dados()
    print(dado1)
    dado2 = tirada_dados()
    print(dado2)
    suma_resultados = suma_resultados + dado1 + dado2
promedio = suma_resultados / num_tiradas*2
print(f"El promedio de tiradas de los dados es: {promedio}")
# Out:
# PROMEDIO DE LA SUMA DE LAS TIRADAS DE DOS DADOS
# ...
# 6
# 4
# 1
# 4
# 1
# 2
# 1
# 6
# 1
# 4
# 4
# 1
# 3
# 2
# 6
# 4
# 2
# 4
# 4
# 3
# 6
# 1
# 5
# 2
# 3
# 2
# 6
# 6
# 1
# 6
# 2
# 2
# 1
# 6
# 2
# 1
# 6
# 4
# 5
# 1
# El promedio de tiradas de los dados es: 13.1

# %% [markdown]
# ### Ejercicio: Reemplazar espacios
#
# **Objetivo:** sustituir todos los espacios en blanco de una frase por puntos y coma (`;`), construyendo una nueva cadena carácter a carácter.
#
# **Entradas:** una frase.
#
# **Salida:** la nueva frase modificada.

# %%
print("REMPLAZAR LOS ESPACIOS DE UNA FRASE CON PUNTO Y COMA")
print("====================================================")

frase = input("Ingrese la frase: ")
nueva_frase = ""
for letra in frase:
    if letra == " ":
        nueva_frase += ";"
    else:
        nueva_frase += letra
print(nueva_frase)
# Out:
# REMPLAZAR LOS ESPACIOS DE UNA FRASE CON PUNTO Y COMA
# ...
# Hola;como;estás?;Te;sentís;bien?

# %% [markdown]
# ### Ejercicio: Estadísticas de números
#
# **Objetivo:** solicitar 6 números enteros, sumar los negativos y calcular el promedio de los positivos.
#
# **Entradas:** 6 números enteros.
#
# **Salida:** suma de negativos y promedio de positivos (si los hay).

# %%
print("ALGORITMO: SUMA DE NEGATIVOS Y PROMEDIO DE POSITIVOS")
print("====================================================")
sumatoria_negativos = 0
sumatoria_positivos = 0
contador_de_positivos = 0
for i in range(6):
    num = int(input("Ingrese un numero entero: "))
    if num < 0:
        sumatoria_negativos += num
    else:
        sumatoria_positivos += num
        contador_de_positivos += 1
print(f"La suma de los numeros negativos es: {sumatoria_negativos}")
if contador_de_positivos > 0:
    print("EL promedio de los numeros positivos es:", sumatoria_positivos / contador_de_positivos)
else:
    print("No se ingresaron numeros positivos")
# Out:
# ALGORITMO: SUMA DE NEGATIVOS Y PROMEDIO DE POSITIVOS
# ...
# La suma de los numeros negativos es: -54
# No se ingresaron numeros positivos

# %% [markdown]
# ### Ejercicio: Sumatoria definida
#
# **Objetivo:** calcular la suma de una cantidad específica de números indicada por el usuario.
#
# **Entradas:** cantidad de iteraciones y luego esa cantidad de números enteros.
#
# **Salida:** suma total.

# %%
print("SUMATORIA DE ITERACIONES")
print("========================")

sumatoria = 0
cantidad_de_iteraciones = int(input("Ingrese el numero iteraciones que desea tener: "))
for i in range(cantidad_de_iteraciones):
    num = int(input("Ingrese un numero entero:"))
    sumatoria += num
print(f"La sumatoria es: {sumatoria}")
# Out:
# SUMATORIA DE ITERACIONES
# ...
# La sumatoria es: 51

# %% [markdown]
# ### Ejercicio: Gematría
#
# **Objetivo:** calcular el valor de una frase sumando la posición de cada una de sus letras en el abecedario (a=1, b=2, etc.).
#
# **Entradas:** una frase.
#
# **Salida:** valor numérico de la gematría.

# %%
print("GEMATRIA")
print("========")


def normaliza_frase(frase):
    caracteres = "áéíóúü"
    normalizados = "aeiouu"
    cadena_nueva = ""
    for letra in frase.lower():
        i = caracteres.find(letra)
        if i >= 0:
            cadena_nueva += normalizados[i]
        else:
            cadena_nueva += letra
    return cadena_nueva


def gematria(frase):
    valor = 0
    abcdario = "abcdefghijklmnñopqrstuvwxyz"
    frase_auxiliar = normaliza_frase(frase)
    for letra in frase_auxiliar:
        if letra in abcdario:
            posicion = abcdario.find(letra)
            valor += posicion + 1
    return valor


frase = input("Ingrese una frase: ")
print(gematria(frase))
abcdario = "abcdefghijklmnñopqrstvwxyz"
posicion = abcdario.find(frase)
# Out:
# GEMATRIA
# ...
# 36

# %% [markdown]
# ### Ejercicio: Palabra Mágica
#
# **Objetivo:** determinar si una frase es "mágica", lo cual se cumple si su valor de gematría es exactamente 21.
#
# **Entradas:** una frase.
#
# **Salida:** `True` o `False`.

# %%
print("PALABRAS MÁGICAS")
print("================")


def normaliza_frase(frase):
    caracteres = "áéíóúü"
    normalizados = "aeiouu"
    cadena_nueva = ""
    for letra in frase.lower():
        i = caracteres.find(letra)
        if i >= 0:
            cadena_nueva += normalizados[i]
        else:
            cadena_nueva += letra
    return cadena_nueva


def gematria(frase):
    valor = 0
    abcdario = "abcdefghijklmnñopqrstuvwxyz"
    frase_auxiliar = normaliza_frase(frase)
    for letra in frase_auxiliar:
        if letra in abcdario:
            posicion = abcdario.find(letra)
            valor += posicion + 1
    return valor

def palabra_magica(frase):
    frase_auxiliar = normaliza_frase(frase)
    gematria_frase = gematria(frase_auxiliar)
    if gematria_frase != 21:
        return False
    return True



frase = input("Ingrese una frase: ")
print(palabra_magica(frase))
# Out:
# PALABRAS MÁGICAS
# ...
# False

# %% [markdown]
# ### Ejercicio: Palíndromo
#
# **Objetivo:** verificar si una frase es un palíndromo (se lee igual de izquierda a derecha que de derecha a izquierda), ignorando tildes (normalización).
#
# **Entradas:** una frase.
#
# **Salida:** `True` si es palíndromo, `False` en caso contrario.

# %%
print("GEMATRIA")
print("========")


def normaliza_frase(frase):
    caracteres = "áéíóúü"
    normalizados = "aeiouu"
    cadena_nueva = ""
    for letra in frase.lower():
        i = caracteres.find(letra)
        if i >= 0:
            cadena_nueva += normalizados[i]
        else:
            cadena_nueva += letra
    return cadena_nueva


def palindromo(frase):
    frase_auxiliar = normaliza_frase(frase)
    frase_original = frase_auxiliar
    frase_invertida = frase_original[::-1]
    if frase_invertida != frase_original:
        return False
    return True


frase = input("Ingrese una frase: ")
print(palindromo(frase))
# Out:
# GEMATRIA
# ...
# False
